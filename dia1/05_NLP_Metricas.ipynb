# %% [markdown]
# # IMPORTAMOS LIBRERIAS Y DESCARGAMOS CORPUS DE LIBROS

# %%
import nltk
nltk.download('book')
from nltk.book import *
import matplotlib.pyplot as plt
import numpy as np
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# # ANALIZAMOS EL LIBRO TEXT1

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.tokens[:10]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.']

# %%
len(text1)
# Out:
# 260819

# %% [markdown]
# ## Medida de riqueza lexica en un texto:
#
# Calcular algunas metricas sobre el texto
#
# Cuando tenemos un texto, es normal que algunas palabras se repitan. Queremos definir cuantas palabras unicas se utilizaron respecto al total de palabras del texto. Cuanto mas grande sea nuestra riqueza lexica, mas palabras diferentes utilizo nuestro autor.
#
# $$ R_l = \frac{\text{total de palabras únicas}}{\text{total de palabras}} = \frac{\text{longitud del vocabulario}}{\text{longitud del texto}}$$

# %% [markdown]
# Primero realizamos la construcción de un vocabulario (identificamos las palabras unicas que hay en el libro)
#
# Utilizamos la funcion [set()](https://docs.python.org/2/library/sets.html), esta toma la lista de tokens y elimina repetidos, dejando una lista de palabras, con una estructura de datos sort. Para convertirlo a otra estructura usamos **sorted()**. Con esta funcion ordenamos alfabeticamente nuestro set y lo convertimos en lista.

# %%
vocabulario = sorted(set(text1))
print(vocabulario[1000:1050])
# Out:
# ['Crew', 'Crish', 'Crockett', 'Cross', 'Crossed', 'Crossing', 'Crotch', 'Crowding', 'Crown', 'Crozetts', 'Cruelty', 'Cruising', 'Cruppered', 'Crusaders', 'Crushed', 'Crying', 'Cuba', 'Curious', 'Curse', 'Cursed', 'Curses', 'Cussed', 'Customs', 'Cut', 'Cutter', 'Cutting', 'Cuvier', 'Cyclades', 'Czar', 'D', 'DAGGOO', 'DAM', 'DANCE', 'DANCING', 'DANIEL', 'DANISH', 'DARKENS', 'DARWIN', 'DAVENANT', 'DEAD', 'DEATH', 'DEBELL', 'DECK', 'DEL', 'DESTROYED', 'DEVIL', 'DICTIONARY', 'DID', 'DIGNITY', 'DISCOVERS']

# %%
rl = len(vocabulario)/len(text1)
rl
# Out:
# 0.07406285585022564

# %% [markdown]
# ## CREAMOS UNA FUNCIÓN PARA MEDIR LA RIQUEZA LEXICA

# %%
def riqueza_lexica(texto):
  vocabulario = sorted(set(texto))
  return len(vocabulario)/len(texto)

riqueza_lexica(text1)
# Out:
# 0.07406285585022564

# %% [markdown]
# # CREAMOS UNA FUNCIÓN PARA MEDIR EL PORCENTAJE DE UNA PALABRA CON RESPECTO AL CORPUS

# %%
def porcentaje_palabra(palabra, texto):
  porcentaje_palabra = 100 * texto.count(palabra)/len(texto)
  return porcentaje_palabra

# %%
text1.count('whale')
# Out:
# 906

# %%
porcentaje_palabra('whale',text1)
# Out:
# 0.3473673313677301

# %% [markdown]
# ## Estadistica del Lenguaje
#
# Los cálculos estadísticos más simples que se pueden efectuar sobre un texto o un corpus son los relacionados con frecuencia de aparición de palabras.
#
# * Podemos construir un diccionario en Python donde las llaves sean las palabras y los valores sean las frecuencias de ocurrencias de esas palabras.
#
# * ejemplo `dic = {'monster': 49 ,  'boat': 54,  ...}`

# %%
# Realizar un for básico, computacionalmete es muy pesado si tenemos muchos tokens
dic = {}
for palabra in set(text1):
  dic[palabra] = text1.count(palabra)
dic
# Out:
# {'writer': 2,
#  'bound': 28,
#  'unreliable': 1,
#  'gurglings': 2,
#  'buckle': 4,
#  'phosphorescence': 1,
#  'bakers': 1,
#  'tepid': 2,
#  'laudanum': 1,
#  'amplified': 2,
#  'summit': 10,
#  'fished': 1,
#  'forlornly': 1,
#  'rusty': 3,
#  'bind': 2,
#  'partake': 1,
#  'cheapest': 1,
#  'bask': 1,
#  'cholera': 2,
#  'pea': 2,
#  'inoffensiveness': 1,
#  'unprincipled': 2,
#  'hunts': 2,
#  'mumbling': 5,
#  'omitted': 5,
#  'praises': 1,
#  'Capting': 4,
#  'monster': 49,
#  'inscrutably': 1,
#  'crescentic': 4,
#  'Clinging': 1,
#  'moose': 2,
#  'babes': 1,
#  'disappears': 3,
#  'revels': 1,
#  'Quitting': 2,
#  'precise': 19,
#  'wandering': 4,
#  'showing': 5,
#  'worn': 11,
#  'digestive': 1,
#  'resident': 1,
#  'Bess': 1,
#  'casement': 1,
#  'Algerine': 1,
#  'Byward': 1,
#  'besooted': 1,
#  'poring': 2,
#  'Saw': 1,
#  'objections': 2,
#  'generations': 6,
#  'fashionables': 1,
#  'sylphs': 1,
#  'properties': 1,
#  'peaceful': 6,
#  'livers': 3,
#  'bloodshed': 1,
#  'continued': 14,
#  'offing': 4,
#  'remaining': 10,
#  'nooks': 3,
#  'slumbers': 3,
#  'Alarmed': 1,
#  'Remembering': 1,
#  'variously': 3,
#  'zig': 1,
#  'eternal': 19,
#  'Summer': 1,
#  'altering': 4,
#  'cautiously': 2,
#  'Power': 1,
#  'bloodthirsty': 2,
#  'stiffening': 1,
#  'BATTLE': 2,
#  'Presbyterians': 1,
#  'moods': 5,
#  'Scales': 1,
#  'rafters': 1,
#  'miserly': 1,
#  'honours': 2,
#  'pitiful': 3,
#  'dost': 13,
#  'cosmopolite': 1,
#  'impious': 4,
#  'angles': 3,
#  'ash': 6,
#  'fountain': 8,
#  'accountable': 1,
#  'steals': 2,
#  'easy': 38,
#  'amain': 1,
#  'systemized': 1,
#  'enveloped': 3,
#  'Cannibal': 1,
#  'temple': 4,
#  'forbearing': 1,
#  'Durand': 1,
#  'cork': 4,
#  'captured': 17,
#  'hears': 5,
#  'shuttlecock': 1,
#  'COWPER': 1,
#  'therein': 5,
#  'chief': 30,
#  'rests': 2,
#  'shrinked': 1,
#  'Dr': 6,
#  'affecting': 1,
#  'TYERMAN': 1,
#  'BOUTON': 1,
#  'strictly': 5,
#  'nailed': 11,
#  'whetstones': 1,
#  'signed': 5,
#  'savannas': 1,
#  'indulge': 1,
#  'devilishness': 1,
#  'emprise': 1,
#  'Islanders': 4,
#  'sadly': 12,
#  'cringed': 2,
#  'parallel': 5,
#  'Forehead': 1,
#  'community': 1,
#  'swell': 11,
#  'brooks': 2,
#  'marines': 3,
#  'wrinkled': 14,
#  'clouds': 12,
#  'reddish': 1,
#  'delegated': 1,
#  'His': 54,
#  'engraven': 1,
#  'Aft': 1,
#  'punctual': 1,
#  'schooner': 5,
#  'Conjuror': 1,
#  'LIFE': 2,
#  'bye': 13,
#  'away': 175,
#  'completing': 1,
#  'obscure': 1,
#  'lunges': 1,
#  'godly': 3,
#  'stubbornness': 1,
#  'underwent': 1,
#  'traps': 2,
#  'conflagrations': 1,
#  'cloudless': 1,
#  'Albemarle': 1,
#  'loiters': 1,
#  'conducted': 2,
#  'strip': 10,
#  'Britons': 1,
#  'part': 149,
#  'exhibition': 2,
#  'wholesome': 2,
#  'implement': 3,
#  'muffle': 1,
#  'hauling': 4,
#  'celestial': 5,
#  'absorbed': 4,
#  'groping': 4,
#  'pert': 1,
#  '118': 1,
#  'luff': 1,
#  'arches': 2,
#  'sinker': 1,
#  'corrupt': 4,
#  'eyed': 9,
#  'sciences': 2,
#  'expand': 6,
#  'overgrowth': 1,
#  'whale': 906,
#  'Martha': 4,
#  'manfully': 1,
#  'less': 51,
#  'Think': 11,
#  'bison': 3,
#  'mythologies': 2,
#  'inveterate': 1,
#  'abandonedly': 1,
#  'autumnal': 1,
#  'braced': 2,
#  'paddling': 1,
#  'tears': 6,
#  'airley': 2,
#  'freely': 11,
#  'comply': 1,
#  'J': 4,
#  'peculiarities': 11,
#  'Forecastle': 2,
#  'Dan': 4,
#  'witchery': 1,
#  'races': 1,
#  'obedient': 2,
#  'Deer': 2,
#  'nostril': 1,
#  'associations': 5,
#  'imparts': 4,
#  'Planted': 1,
#  'bumpkins': 2,
#  'startling': 3,
#  'Main': 2,
#  'attenuated': 1,
#  'permit': 3,
#  'clothing': 3,
#  'generous': 5,
#  'objectionable': 1,
#  'hatch': 7,
#  'consequently': 3,
#  'OUT': 2,
#  'afforded': 5,
#  'revivified': 1,
#  'chip': 5,
#  'Massa': 3,
#  'Abednego': 1,
#  'Like': 23,
#  'while': 216,
#  'woodland': 1,
#  'represent': 2,
#  'assembled': 3,
#  'congeal': 1,
#  'Italy': 1,
#  'ubiquity': 1,
#  'fasces': 1,
#  'Hudson': 2,
#  'Supposing': 1,
#  'vital': 10,
#  'clumped': 1,
#  'unaccompanied': 2,
#  'exordium': 1,
#  'Which': 6,
#  'Didn': 11,
#  'descry': 1,
#  'vibrations': 1,
#  'injury': 2,
#  'reflected': 2,
#  'General': 4,
#  'wrenched': 6,
#  'forlornness': 1,
#  'Cassock': 1,
#  'Put': 1,
#  'Cave': 1,
#  'MUTINEER': 1,
#  'dramatic': 3,
#  'demands': 1,
#  'blade': 8,
#  'thwack': 1,
#  'faintest': 2,
#  'imputed': 3,
#  'adown': 1,
#  'toasting': 1,
#  'assumed': 5,
#  'playful': 3,
#  'traditional': 1,
#  'approach': 5,
#  'bolder': 1,
#  'governor': 5,
#  'Curse': 2,
#  'chaste': 1,
#  'steward': 16,
#  'language': 6,
#  'suckingly': 1,
#  'OFFICIO': 1,
#  'vacancy': 3,
#  'Guernsey': 11,
#  'habitude': 1,
#  'fork': 3,
#  'scrubbed': 1,
#  'obscures': 1,
#  'copestone': 2,
#  'pondered': 4,
#  'greatly': 6,
#  'depression': 2,
#  'TAKING': 1,
#  'hides': 3,
#  'steers': 2,
#  'ing': 1,
#  'fanatic': 2,
#  'possibly': 29,
#  'Free': 1,
#  'whereon': 4,
#  'resolution': 3,
#  'Chase': 3,
#  'receive': 8,
#  'Despairing': 1,
#  'ork': 1,
#  'Charity': 7,
#  'deepening': 1,
#  'manner': 37,
#  'idolators': 1,
#  'appallingly': 1,
#  'warringly': 1,
#  'Rue': 1,
#  'boot': 2,
#  'Massachusetts': 3,
#  'peg': 2,
#  'sweetly': 2,
#  'Concerning': 2,
#  'market': 6,
#  'BIT': 1,
#  'martyr': 1,
#  '99': 1,
#  'scheming': 1,
#  'horseman': 3,
#  'gaff': 2,
#  'ADVENTURES': 1,
#  'Queequeg': 252,
#  'forcibly': 3,
#  'Pulpit': 1,
#  'Leviathans': 7,
#  'scarcely': 8,
#  'plug': 4,
#  'turbid': 2,
#  'sober': 7,
#  'adolescence': 1,
#  'Locks': 2,
#  'churning': 6,
#  'Returning': 2,
#  'roses': 4,
#  'soldiers': 3,
#  'builder': 1,
#  'second': 54,
#  'Brute': 1,
#  'bids': 1,
#  'wails': 2,
#  'surpass': 1,
#  'corkscrewed': 1,
#  'Lying': 2,
#  'hamlets': 1,
#  'spy': 2,
#  'jugglers': 1,
#  'vacuum': 1,
#  'tube': 6,
#  'brig': 3,
#  'First': 24,
#  'Randolphs': 1,
#  'Martial': 1,
#  'lifted': 16,
#  'Malay': 1,
#  'patronising': 1,
#  'blew': 8,
#  'Bourbons': 1,
#  'crags': 1,
#  'Desmarest': 2,
#  'unquestionable': 3,
#  'islanders': 1,
#  'oppositely': 1,
#  'babe': 1,
#  'latently': 1,
#  'industrious': 1,
#  'impertinent': 2,
#  'dry': 14,
#  'catastrophe': 3,
#  'Crammer': 1,
#  'pencil': 5,
#  'furthest': 5,
#  'whelmed': 3,
#  'Why': 48,
#  'amputations': 1,
#  'series': 4,
#  'scarcity': 1,
#  'cabinet': 1,
#  'stupid': 1,
#  'satisfaction': 4,
#  '?"--': 6,
#  'tailed': 3,
#  'Pusie': 1,
#  'try': 49,
#  'Yojo': 17,
#  'indebtedness': 1,
#  'CAULKING': 1,
#  'bigot': 1,
#  'fleeces': 1,
#  'exceeds': 1,
#  'closer': 8,
#  'lodge': 3,
#  'Rondeletius': 1,
#  'foundations': 4,
#  'adequate': 2,
#  'leviathans': 10,
#  'muffledness': 1,
#  'ahoy': 6,
#  'antidote': 1,
#  'typhoons': 1,
#  'wakefulness': 1,
#  'pinny': 1,
#  'ignores': 1,
#  'ploughing': 2,
#  'bowstring': 1,
#  'Gulfweed': 1,
#  'gums': 2,
#  'flush': 1,
#  'meddling': 1,
#  'retreated': 4,
#  'voyagers': 1,
#  'prey': 14,
#  'shabbily': 1,
#  'contentedly': 1,
#  'Fisheries': 1,
#  'taunts': 1,
#  'tendency': 4,
#  'chestnuts': 2,
#  'WINDOW': 1,
#  'freedom': 2,
#  'acquiesced': 1,
#  'ENGLISH': 3,
#  'unwritten': 2,
#  'tigress': 1,
#  'indomitable': 1,
#  'miss': 1,
#  'wipe': 1,
#  'ripening': 1,
#  'Thy': 7,
#  'prepare': 2,
#  'spans': 3,
#  'granting': 2,
#  'richer': 2,
#  'expending': 1,
#  'holier': 1,
#  'unaccustomed': 1,
#  'Apply': 1,
#  'Accessory': 1,
#  'unmurmuringly': 1,
#  'regardful': 1,
#  'that': 2982,
#  'Decapitation': 1,
#  'fiddler': 1,
#  'pampered': 1,
#  'spreading': 2,
#  'shaping': 2,
#  'ebonness': 1,
#  'pealing': 1,
#  'Tho': 1,
#  'jewellers': 2,
#  'plumed': 3,
#  'Peering': 1,
#  'luffs': 1,
#  'Upharsin': 1,
#  'VISITS': 1,
#  'blueness': 1,
#  'Grub': 1,
#  'action': 9,
#  'limbered': 1,
#  'Instead': 1,
#  'equinoctial': 1,
#  'parcelling': 1,
#  'fabled': 2,
#  'behead': 1,
#  'darbies': 1,
#  'bible': 1,
#  'flock': 1,
#  'weaves': 1,
#  'WAL': 1,
#  'enjoined': 1,
#  'gritted': 2,
#  'furrow': 1,
#  'Spaniard': 3,
#  'Squeeze': 2,
#  'usurper': 1,
#  'nursery': 3,
#  'fattest': 1,
#  'begone': 1,
#  'literature': 1,
#  'undeniable': 2,
#  'Once': 5,
#  'freed': 2,
#  'awarded': 1,
#  'partially': 4,
#  'Caryatid': 1,
#  'gaze': 17,
#  'furiously': 6,
#  'comest': 1,
#  'influence': 9,
#  'dip': 5,
#  'saplings': 1,
#  'pronounced': 5,
#  'SHE': 2,
#  'schoolmasters': 1,
#  'torment': 1,
#  'Transported': 1,
#  'PACIFIC': 2,
#  'undoubted': 2,
#  'manoeuvres': 1,
#  'desperadoes': 2,
#  'elaborately': 1,
#  'wildly': 9,
#  'Jago': 1,
#  'bones': 48,
#  'preparation': 3,
#  'endeavors': 4,
#  'odorless': 1,
#  'Wapping': 2,
#  'Dropping': 2,
#  '--(': 4,
#  'documents': 2,
#  'Killer': 2,
#  'predicament': 1,
#  'maw': 3,
#  'press': 3,
#  'goin': 5,
#  'Originally': 1,
#  'leering': 2,
#  'lively': 13,
#  'John': 11,
#  'think': 111,
#  'tries': 1,
#  'Jungfrau': 5,
#  'renounce': 2,
#  'boast': 2,
#  'belayed': 1,
#  'lustre': 4,
#  'BURKE': 2,
#  'incuriously': 1,
#  'happiness': 2,
#  'crying': 3,
#  'plaited': 4,
#  'attribute': 1,
#  'ready': 40,
#  'corporal': 1,
#  'whoop': 1,
#  'scheme': 3,
#  'OAKES': 1,
#  'aback': 2,
#  'beadle': 2,
#  'emblazonings': 1,
#  'tightly': 3,
#  'ridge': 3,
#  'assuring': 1,
#  'cranes': 3,
#  'dazed': 1,
#  'tomahawk': 17,
#  'terrify': 3,
#  'Del': 1,
#  'another': 106,
#  'vassal': 1,
#  'floated': 18,
#  'coating': 1,
#  'Picture': 1,
#  'sported': 1,
#  'extremes': 1,
#  'wearisome': 1,
#  'oh': 36,
#  'enable': 4,
#  'performances': 3,
#  'stayed': 7,
#  'impairing': 1,
#  'girdled': 3,
#  'oddish': 1,
#  'East': 10,
#  'Dominic': 2,
#  'reef': 4,
#  'Loose': 14,
#  'edging': 1,
#  'ballasted': 2,
#  'pace': 7,
#  'cudgelling': 1,
#  'religious': 2,
#  ';--': 64,
#  'entering': 6,
#  'pry': 4,
#  'surf': 5,
#  'wonderfully': 2,
#  'jingling': 2,
#  'illimitable': 1,
#  'dines': 1,
#  'cradle': 1,
#  'remonstrated': 1,
#  'diffused': 3,
#  'forging': 3,
#  'Manx': 1,
#  'significance': 6,
#  'overlays': 1,
#  'means': 44,
#  'herself': 7,
#  'peeringly': 1,
#  'paced': 9,
#  'Penetrating': 1,
#  'masses': 8,
#  'unmethodically': 2,
#  'trump': 3,
#  'hoofs': 3,
#  'objection': 2,
#  'reiterating': 1,
#  'kelson': 3,
#  'vicar': 1,
#  'octavo': 1,
#  'Poland': 2,
#  'dissemble': 1,
#  'Marking': 1,
#  'sepulchral': 2,
#  'sordidness': 1,
#  '90': 1,
#  'unintelligence': 1,
#  'HEARS': 1,
#  'tinkering': 1,
#  'rule': 6,
#  'mad': 36,
#  'mammiferous': 1,
#  'Baden': 2,
#  'bricks': 1,
#  'Thrusted': 1,
#  'hundred': 50,
#  'unconscious': 6,
#  'proud': 8,
#  'strangely': 29,
#  'rallied': 3,
#  'caution': 2,
#  'opine': 3,
#  'hoisting': 11,
#  'creativeness': 1,
#  'struggle': 2,
#  'sunk': 7,
#  'SOUTH': 1,
#  'deplored': 2,
#  'Hope': 7,
#  'Locke': 1,
#  'My': 22,
#  'reasonableness': 1,
#  'employments': 2,
#  'quickest': 2,
#  'incrustations': 1,
#  'discharge': 1,
#  'tideless': 1,
#  'harbours': 1,
#  'Imprimis': 1,
#  'uncatastrophied': 1,
#  'maliciously': 1,
#  'depicted': 4,
#  'interruptions': 2,
#  'assailing': 1,
#  'Righteousness': 1,
#  'fighting': 5,
#  'dogged': 1,
#  'reeved': 1,
#  'feigned': 1,
#  'gulfs': 1,
#  'Dutch': 24,
#  'disputes': 1,
#  'superstition': 4,
#  'denying': 3,
#  'sand': 11,
#  'Newcastle': 1,
#  '115': 1,
#  'Caramba': 1,
#  'vapoury': 5,
#  'Fain': 1,
#  'knocking': 7,
#  'thin': 17,
#  'plying': 3,
#  'quig': 1,
#  'snarls': 1,
#  'like': 624,
#  'grotesqueness': 1,
#  'twice': 10,
#  'horror': 12,
#  'card': 3,
#  'nurse': 3,
#  'yaw': 2,
#  'taste': 11,
#  'combed': 1,
#  'Glacier': 2,
#  'declaring': 3,
#  'Saturday': 5,
#  'remains': 24,
#  'KINROSS': 1,
#  'slowly': 47,
#  'strangest': 3,
#  'pennant': 1,
#  'throbbings': 1,
#  '.,': 7,
#  'philosopher': 4,
#  'employment': 1,
#  'bush': 1,
#  'melt': 1,
#  'Muezzin': 1,
#  'inextricable': 1,
#  'fastenings': 1,
#  'invocation': 1,
#  'casket': 3,
#  'stratagem': 1,
#  'buckskin': 3,
#  'overflowing': 2,
#  'recreate': 1,
#  'sunset': 8,
#  'dripping': 9,
#  'seized': 18,
#  'sleek': 2,
#  'OR': 5,
#  'draught': 5,
#  'l': 1,
#  'dining': 3,
#  'County': 1,
#  'vats': 1,
#  'disappeared': 15,
#  'flailing': 1,
#  'mumbled': 1,
#  'traverse': 1,
#  'conspired': 1,
#  'Sub': 7,
#  'slanting': 4,
#  'valise': 1,
#  'Grant': 1,
#  'descendants': 1,
#  'cash': 5,
#  'languishing': 1,
#  'greedy': 1,
#  'spinal': 8,
#  'treacherously': 2,
#  'dissimilar': 2,
#  'reserved': 9,
#  'reduced': 2,
#  'coffee': 6,
#  'abode': 2,
#  'helped': 15,
#  'elapse': 2,
#  'dreamy': 4,
#  'fearfulness': 3,
#  'dan': 3,
#  'embattled': 2,
#  'brawn': 2,
#  'ham': 1,
#  'encountered': 16,
#  '39': 1,
#  'regained': 1,
#  'man': 508,
#  'accosted': 4,
#  'frames': 1,
#  'crockery': 2,
#  'erring': 1,
#  'triangularly': 1,
#  'blundering': 2,
#  'vigorous': 9,
#  'proprietors': 3,
#  'kindling': 2,
#  'investigate': 1,
#  'medals': 1,
#  'thoroughly': 2,
#  'flitting': 6,
#  'delirium': 5,
#  'splinters': 5,
#  'bet': 1,
#  'healed': 1,
#  'crooked': 8,
#  'free': 31,
#  'Erie': 4,
#  'indolently': 2,
#  'investigation': 1,
#  'front': 25,
#  'escaped': 10,
#  'Delta': 1,
#  'ticking': 1,
#  'queer': 44,
#  'TRUE': 1,
#  'elm': 1,
#  'Yankee': 1,
#  'ordinary': 19,
#  'Finding': 1,
#  'busy': 7,
#  '1840': 1,
#  'boarding': 5,
#  'ABOUT': 1,
#  'ice': 27,
#  'exact': 8,
#  'thou': 232,
#  'private': 13,
#  'Golden': 3,
#  'changeful': 1,
#  'awaiting': 6,
#  'gayer': 1,
#  'angrily': 1,
#  'begotten': 1,
#  'mechanically': 8,
#  'repeating': 1,
#  'sneezing': 1,
#  'mistakes': 2,
#  'villa': 1,
#  'Cologne': 5,
#  'vanity': 2,
#  'resisted': 1,
#  'ibis': 1,
#  'wrapall': 1,
#  'soothing': 3,
#  'Contrasted': 2,
#  'vaulted': 2,
#  'effects': 2,
#  'appetite': 3,
#  'stems': 1,
#  'hinge': 2,
#  'cook': 41,
#  'Johnson': 3,
#  'flowers': 4,
#  'primitive': 3,
#  'attendance': 2,
#  'Vesuvius': 2,
#  'bravery': 2,
#  'subtract': 1,
#  'Humpback': 1,
#  'stillness': 3,
#  'speaks': 4,
#  'foreseeing': 2,
#  'jibs': 1,
#  'smackin': 1,
#  'pallid': 4,
#  'curled': 6,
#  'foamingly': 1,
#  'pleased': 9,
#  'celerity': 3,
#  'invited': 5,
#  'meaning': 17,
#  'perpendicular': 11,
#  'direst': 3,
#  'swamp': 1,
#  'Plum': 1,
#  'battles': 1,
#  'Mark': 6,
#  'adroop': 2,
#  'Hands': 6,
#  'call': 52,
#  'spool': 2,
#  'Bellies': 1,
#  'inconsiderable': 3,
#  'Header': 4,
#  'unsuspecting': 1,
#  'PREFACE': 1,
#  'bowlines': 3,
#  'plums': 1,
#  'HOLY': 1,
#  'inkstand': 1,
#  'operating': 1,
#  'thanked': 1,
#  'princes': 2,
#  'HVALT': 2,
#  'abominate': 1,
#  'imminent': 5,
#  'mop': 1,
#  'Breakfast': 1,
#  'needing': 1,
#  'resolved': 13,
#  'unmistakably': 1,
#  'assured': 6,
#  'sticking': 6,
#  'grasped': 6,
#  'blush': 1,
#  'Newfoundland': 2,
#  'Hemp': 2,
#  'Patience': 1,
#  'lurking': 7,
#  'concussions': 1,
#  'gibbering': 1,
#  'eats': 3,
#  'amplify': 1,
#  'counties': 1,
#  'confusion': 3,
#  'glimpse': 10,
#  'odious': 1,
#  'considered': 14,
#  'unstreaked': 1,
#  'verdure': 7,
#  'grooves': 4,
#  'unstranded': 1,
#  'direct': 11,
#  'department': 2,
#  'hay': 4,
#  'gaudiest': 1,
#  'stuffed': 5,
#  'cobblestones': 1,
#  'gull': 3,
#  'Cellini': 1,
#  'potatoes': 1,
#  'economical': 2,
#  'monotonous': 1,
#  'ermine': 1,
#  'fairy': 3,
#  'soundings': 6,
#  'bastions': 1,
#  'Retribution': 1,
#  'always': 80,
#  'traced': 2,
#  'writhing': 2,
#  'offensively': 1,
#  'parlor': 6,
#  'attains': 1,
#  'Stab': 1,
#  'precautionary': 1,
#  'bucks': 1,
#  'jungle': 1,
#  'polar': 2,
#  'exclusion': 1,
#  'leads': 3,
#  'Hah': 1,
#  'early': 11,
#  'refuse': 6,
#  'Gibraltar': 2,
#  'tastefully': 1,
#  'Bonapartes': 1,
#  'kindred': 5,
#  'PITCHING': 1,
#  'corkscrew': 1,
#  'Day': 4,
#  'abiding': 2,
#  'Sherry': 1,
#  'applied': 7,
#  'happenest': 1,
#  'quietude': 4,
#  'owned': 5,
#  'Joppa': 8,
#  'opinion': 14,
#  'added': 25,
#  'well': 174,
#  'invitingly': 1,
#  'design': 4,
#  'giraffe': 1,
#  'waits': 2,
#  'pronouncing': 3,
#  'MOVING': 1,
#  'exploit': 2,
#  'uncheered': 1,
#  'tame': 4,
#  'devoutly': 2,
#  'fatalistic': 1,
#  'mown': 2,
#  'groom': 1,
#  'mourning': 2,
#  'mite': 1,
#  'sighed': 2,
#  'flurry': 3,
#  'yourselves': 7,
#  'passiveness': 1,
#  'eyelids': 1,
#  'supported': 2,
#  'feline': 1,
#  'courts': 1,
#  'clout': 2,
#  'walking': 8,
#  'Admirals': 1,
#  'phrensies': 2,
#  'pillaged': 1,
#  'widow': 7,
#  'bodied': 1,
#  'reproach': 1,
#  '1492': 1,
#  'hovered': 6,
#  'indistinctness': 1,
#  'nominally': 4,
#  'clubs': 1,
#  'purple': 6,
#  'pods': 4,
#  'frisky': 1,
#  'moderately': 2,
#  'navel': 2,
#  'uneasy': 2,
#  'repeated': 20,
#  'ungraspable': 1,
#  'SONG': 2,
#  'liquid': 2,
#  'debtor': 1,
#  'Hail': 1,
#  'depended': 2,
#  'messmates': 1,
#  'rides': 2,
#  'incantation': 2,
#  'unresting': 2,
#  'almanac': 2,
#  'traitors': 2,
#  'Lavater': 3,
#  'pomatum': 1,
#  'peals': 1,
#  'balls': 8,
#  'billed': 1,
#  'death': 71,
#  'OCEAN': 2,
#  'shaggy': 7,
#  'tutelary': 1,
#  'betoken': 1,
#  'rayther': 1,
#  'Comparing': 1,
#  'UP': 1,
#  'Langsdorff': 5,
#  'HOMINUM': 1,
#  'Wolf': 2,
#  'piloted': 1,
#  'Noah': 8,
#  'contemptibly': 1,
#  'aspects': 5,
#  'attic': 1,
#  'Crowding': 1,
#  'sled': 1,
#  'freshets': 2,
#  'ISOLATO': 1,
#  'Wants': 1,
#  'seize': 8,
#  'impart': 2,
#  'immaterial': 1,
#  'blossoms': 1,
#  'work': 62,
#  'Fuego': 1,
#  'Again': 9,
#  'pennies': 1,
#  ...}

# %% [markdown]
# # DISTRIBUCIONES USANDO FREQDIST DE NLTK

# %%
from nltk.book import FreqDist
fdist = FreqDist(text1)
fdist.most_common(10)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982)]

# %%
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
fdist['whale']
# Out:
# 906

# %% [markdown]
# # FILTRADO AVANZADOS USANDO STOPWORDS

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'these', 'this', 'whom', 'needn', 'before', 'nor', 'wasn', 'above', 'other', 'about', 'ourselves', "it'd", 'same', "haven't", 'over', 'ours', 'both', 'at', 'once', 'further', 'his', "hadn't", 'being', 'him', 'some', 'wouldn', 'y', "shan't", 'off', 'few', 'we', 'them', "she'll", "he'd", 'their', "won't", 'have', 'yourselves', 'shouldn', 'after', 'do', 'has', "hasn't", "we'll", 'when', 'are', 'in', "i've", "they'll", 'who', 'out', 'those', 'just', 'through', "aren't", 'is', 'ain', 'own', 'what', 'only', 'was', 'but', 've', 'there', 'hadn', "it'll", 'myself', 'd', 'on', 's', 'himself', 'can', 'should', 'how', 'isn', 'you', 'why', 'weren', 'aren', 'themselves', 'such', 'hasn', 'me', 'until', 'not', 'than', 'your', "i'd", "we've", "i'm", 'down', "should've", 'she', 'that', 'the', 'below', 'a', 'doing', 'up', 'be', "needn't", 'to', "doesn't", "shouldn't", 'shan', "that'll", "it's", 'and', 'very', 'll', 'between', 'having', 'again', 'here', 'my', "they're", 'mightn', 'didn', 'more', "wouldn't", "you're", "you've", "didn't", 'if', 'm', 'during', 'won', "don't", 'of', "you'd", "he's", "we're", 'our', 'with', "they'd", "mightn't", 'haven', 'does', 'from', 'by', 'don', 'i', 'its', 'while', "isn't", 'yours', 'mustn', "wasn't", 'now', "you'll", 'been', 'for', 'where', 'did', "they've", 'he', 'against', 'as', 'or', 'an', "she'd", 'into', "she's", 't', 'under', 'because', 'her', 'itself', 'theirs', 'o', 'it', "mustn't", 're', 'doesn', 'which', 'ma', 'will', 'had', "we'd", 'they', 'too', 'am', 'no', "i'll", 'yourself', 'all', 'herself', 'hers', "he'll", 'most', 'then', 'so', 'couldn', 'were', 'any', "couldn't", 'each', "weren't"}

# %%
words = [word.lower() for word in text1 if word.isalpha()]
filtered_words = [word for word in words if word not in stop_words]
print(filtered_words[:10])
# Out:
# ['moby', 'dick', 'herman', 'melville', 'etymology', 'supplied', 'late', 'consumptive', 'usher', 'grammar']

# %%
fdist_filtered = FreqDist(filtered_words)
fdist_filtered.most_common(10)
# Out:
# [('whale', 1226),
#  ('one', 921),
#  ('like', 647),
#  ('upon', 566),
#  ('man', 527),
#  ('ship', 518),
#  ('ahab', 511),
#  ('ye', 472),
#  ('sea', 455),
#  ('old', 450)]

# %%
fdist_filtered.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

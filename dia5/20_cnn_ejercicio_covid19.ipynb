# %% [markdown]
# # RED NEURONAL CONVOLUCIONAL PARA CLASIFICACION DE IMAGENES RX CON NEUMONIA POR COVID 19

# %% [markdown]
# ## DATASET : [KAGGLE](https://www.kaggle.com/datasets/khoongweihao/covid19-xray-dataset-train-test-sets/data)

# %% [markdown]
# # CARGAMOS DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
base_dir = '/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir,'validation')
test_dir = os.path.join(base_dir,'test')
print(train_dir)
print(validation_dir)
print(test_dir)
# Out:
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/train
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/validation
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/test

# %%
train_normal_dir = os.path.join(train_dir, 'NORMAL')
train_pneumonia_dir = os.path.join(train_dir, 'PNEUMONIA')

validation_normal_dir = os.path.join(validation_dir, 'NORMAL')
validation_pneumonia_dir = os.path.join(validation_dir, 'PNEUMONIA')

test_normal_dir = os.path.join(test_dir, 'NORMAL')
test_pneumonia_dir = os.path.join(test_dir, 'PNEUMONIA')

print(train_normal_dir)
print(train_pneumonia_dir)
print(validation_normal_dir)
print(validation_pneumonia_dir)
print(test_normal_dir)
print(test_pneumonia_dir)
# Out:
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/train/NORMAL
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/train/PNEUMONIA
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/validation/NORMAL
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/validation/PNEUMONIA
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/test/NORMAL
# /content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/test/PNEUMONIA

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def mostrar_imagenes_aleatorias(directorio, num_imagenes=5):
    # Obtener lista de archivos de imagen en el directorio
    imagenes = os.listdir(directorio)

    # Filtrar archivos para obtener solo las imágenes (por ejemplo, con extensiones jpg o png)
    imagenes = [img for img in imagenes if img.endswith(('.jpg', '.jpeg', '.png'))]

    # Seleccionar imágenes aleatorias
    imagenes_aleatorias = random.sample(imagenes, min(num_imagenes, len(imagenes)))

    # Mostrar las imágenes seleccionadas
    for img_name in imagenes_aleatorias:
        img_path = os.path.join(directorio, img_name)
        img = mpimg.imread(img_path)

        plt.figure()
        plt.imshow(img)
        plt.title(img_name)
        plt.axis('off')  # Ocultar los ejes
        plt.show()

# %%
dataset_dir = [train_normal_dir,train_pneumonia_dir,validation_normal_dir,validation_pneumonia_dir,test_normal_dir,test_pneumonia_dir]
for img_dir in dataset_dir:
  mostrar_imagenes_aleatorias(img_dir,num_imagenes=1)

# %%
for img_dir in dataset_dir:
  print(f" en directorio :{img_dir} hay {len(os.listdir(img_dir))} imagenes")
# Out:
#  en directorio :/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/train/NORMAL hay 74 imagenes
#  en directorio :/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/train/PNEUMONIA hay 74 imagenes
#  en directorio :/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/validation/NORMAL hay 10 imagenes
#  en directorio :/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/validation/PNEUMONIA hay 10 imagenes
#  en directorio :/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/test/NORMAL hay 6 imagenes
#  en directorio :/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO6-DEEPLEARNING/dataset_covid19/test/PNEUMONIA hay 6 imagenes

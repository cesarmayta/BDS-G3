# %% [markdown]
# # PROYECTO FINAL MODULO 5: ENTRENAMIENTO DE MODELO DE MACHINE LEARNING PARA DETERMINAR SI UN PACIENTE SUFRE DE ANEMIA

# %% [markdown]
# ## FUENTE : [DATOS ABIERTOS](https://www.datosabiertos.gob.pe/dataset/morbilidad-anemia)

# %%
# !pip install pyjanitor
import janitor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATASET_PATH = '/content/drive/MyDrive/CODIGO.EDU.PE/CIENCIA DE DATOS/NOTEBOOKS/MODULO5-MACHINELEARNING/TRABAJOFINAL/TB_ANEMIA.csv'
df_anemia = pd.read_csv(DATASET_PATH,sep = ";")
df_anemia.head(10)
# Out:
#    id_persona  Edad Tipo_edad Sexo  id_ubigeo  Fecha_atencion Diagnostico  \
# 0    40971314     2         A    M        NaN        20230522        D649
# 1    39270343     4         A    M     1128.0        20211122        D509
# 2    39270343     4         A    M     1128.0        20211129        D509
# 3    39155787     3         A    F     1128.0        20210527        D509
# 4    36178995     2         A    F     1299.0        20210215        D509
# 5    38926264     4         A    M     1506.0        20211113        D509
# 6    39141175     1         A    M     1128.0        20210220        D509
# 7    40229751     2         A    M     1278.0        20221120        D509
# 8    39603123     1         A    M     1278.0        20210428        D509
# 9    39105165     1         A    M     1128.0        20210106        D509
#
#   Tipo_Dx  id_eess
# 0       D     6203
# 1       D    10836
# 2       D    10836
# 3       D    10836
# 4       D     6079
# 5       D     7475
# 6       D     6856
# 7       D     4416
# 8       D     4416
# 9       D    10836
